# %%
import pandas as pd
import os
os.chdir("F:\PML\Datasets")
from sklearn.linear_model import LinearRegression, Ridge , Lasso, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score
from sklearn.preprocessing import PolynomialFeatures
import numpy as np

# %%
housing = pd.read_csv(r"F:\PML\Cases\Real Estate\Housing.csv")
df_dum = pd.get_dummies(housing, drop_first=True)

# %%
X = df_dum.drop('price', axis=1)
y = df_dum['price']

# %% [markdown]
# #### elastic

# %%
params = {'alpha': np.linspace(0.001, 10, 30),'l1_ratio': np.linspace(0,1 ,10)}
kfold = KFold(n_splits=5, shuffle=True, random_state=23)
elastic = ElasticNet()
gcv = GridSearchCV(elastic, cv=kfold, param_grid=params)
gcv.fit(X,y)

#gcv.cv_results_ gives o/p as dictionary.
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.297e+10, tolerance: 3.188e+07 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
print(gcv.best_params_)
print(gcv.best_score_)
best_el = gcv.best_estimator_
dict(zip(X.columns, best_el.coef_))
# Out:
# {'alpha': 0.001, 'l1_ratio': 0.0}
# 0.6495961200305325
# {'lotsize': 3.554771487494984,
#  'bedrooms': 1845.6815674907518,
#  'bathrms': 14282.048243281788,
#  'stories': 6568.591048308691,
#  'garagepl': 4253.425837440132,
#  'driveway_yes': 6635.537268158322,
#  'recroom_yes': 4503.604552726467,
#  'fullbase_yes': 5451.730235409031,
#  'gashw_yes': 12519.271589029866,
#  'airco_yes': 12556.668300869731,
#  'prefarea_yes': 9317.38333813172}

# %% [markdown]
# #### ridge

# %%
ridge = Ridge()
params = {'alpha': [0.001, 0.01, 0.1, 1, 2, 5]}
kfold = KFold(n_splits=5, shuffle=True, random_state=23)
gcv_ri = GridSearchCV(ridge, cv=kfold, param_grid=params)
gcv_ri.fit(X, y)
print(gcv_ri.best_params_)
print(gcv_ri.best_score_)
# Out:
# {'alpha': 5}
# 0.6504126854492416

# %% [markdown]
# #### Unlabelled data

# %%
tst = pd.read_csv(r"F:\PML\Cases\Real Estate\tstHousing.csv")
tst.head()
# Out:
#    lotsize  bedrooms  bathrms  stories driveway recroom fullbase gashw airco  \
# 0     3450         3        1        2      yes      no      yes    no    no
# 1     2309         1        1        1       no      no       no    no    no
# 2     8940         2        2        3      yes      no      yes   yes   yes
# 3     5810         3        1        2       no     yes       no    no    no
#
#    garagepl prefarea
# 0         1       no
# 1         0       no
# 2         1      yes
# 3         0       no

# %%
dum_tst = pd.get_dummies(tst, drop_first=True)
dum_tst
# Out:
#    lotsize  bedrooms  bathrms  stories  garagepl  driveway_yes  recroom_yes  \
# 0     3450         3        1        2         1          True        False
# 1     2309         1        1        1         0         False        False
# 2     8940         2        2        3         1          True        False
# 3     5810         3        1        2         0         False         True
#
#    fullbase_yes  gashw_yes  airco_yes  prefarea_yes
# 0          True      False      False         False
# 1         False      False      False         False
# 2          True       True       True          True
# 3         False      False      False         False

# %% [markdown]
# ##### We predict with ridge regression object as R2 score for Ridge came out to be the best.

# %%
best_ri = gcv_ri.best_estimator_
tst['Predict_Price'] = best_ri.predict(dum_tst)
tst
# Out:
#    lotsize  bedrooms  bathrms  stories driveway recroom fullbase gashw airco  \
# 0     3450         3        1        2      yes      no      yes    no    no
# 1     2309         1        1        1       no      no       no    no    no
# 2     8940         2        2        3      yes      no      yes   yes   yes
# 3     5810         3        1        2       no     yes       no    no    no
#
#    garagepl prefarea  Predict_Price
# 0         1       no   57933.295246
# 1         0       no   27264.018220
# 2         1      yes  127719.912270
# 3         0       no   54931.593384
