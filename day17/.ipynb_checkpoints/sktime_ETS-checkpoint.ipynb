# %%
# !pip install sktime
# Out:
# Collecting sktime
#   Downloading sktime-0.25.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from sktime) (1.26.3)
# Requirement already satisfied: packaging in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from sktime) (23.1)
# Requirement already satisfied: pandas<2.2.0,>=1.1 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from sktime) (2.1.4)
# Collecting scikit-base<0.7.0 (from sktime)
#   Downloading scikit_base-0.6.2-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: scikit-learn<1.4.0,>=0.24 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from sktime) (1.2.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from sktime) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from pandas<2.2.0,>=1.1->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from pandas<2.2.0,>=1.1->sktime) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from pandas<2.2.0,>=1.1->sktime) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from scikit-learn<1.4.0,>=0.24->sktime) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from scikit-learn<1.4.0,>=0.24->sktime) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.2.0,>=1.1->sktime) (1.16.0)
# Downloading sktime-0.25.0-py3-none-any.whl (21.7 MB)
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    ---- ----------------------------------- 2.7/21.7 MB 57.5 MB/s eta 0:00:01
#    -------------- ------------------------- 8.1/21.7 MB 86.5 MB/s eta 0:00:01
#    ------------------------- -------------- 13.6/21.7 MB 110.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 19.0/21.7 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  21.7/21.7 MB 131.2 MB/s eta 0:00:01
#    ---------------------------------------  21.7/21.7 MB 131.2 MB/s eta 0:00:01
#    ---------------------------------------- 21.7/21.7 MB 65.5 MB/s eta 0:00:00
# Downloading scikit_base-0.6.2-py3-none-any.whl (122 kB)
#    ---------------------------------------- 0.0/122.9 kB ? eta -:--:--
#    ---------------------------------------- 122.9/122.9 kB ? eta 0:00:00
# Installing collected packages: scikit-base, sktime
# Successfully installed scikit-base-0.6.2 sktime-0.25.0

# %%
import pandas as pd
from sktime.utils.plotting import plot_series
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.ets import AutoETS
import matplotlib.pyplot as plt
from sktime.forecasting.base import ForecastingHorizon
from sktime.performance_metrics.forecasting import mean_squared_error
from sktime.forecasting.exp_smoothing import ExponentialSmoothing
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\dask\dataframe\_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 11.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(

# %%
df = pd.read_csv("F:\PML\Datasets\monthly-milk-production-pounds-p.csv",index_col=0)
df.head()
# Out:
#          Milk
# Month
# 1962-01   589
# 1962-02   561
# 1962-03   640
# 1962-04   656
# 1962-05   727

# %%
idx = pd.to_datetime( df.index ).to_period("M")
df.index = idx

# %% [markdown]
# Plot:

# %%
plot_series(df)
plt.show()
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
y = df['Milk']
y_train, y_test = temporal_train_test_split(y,test_size=12)

# %%
plot_series(y_train, y_test, labels=["y_train", "y_test"])
plt.show()
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Speciying the Forecasting Horizon:

# %%
fh = ForecastingHorizon(y_test.index,is_relative=False)
fh
# Out:
# ForecastingHorizon(['1975-01', '1975-02', '1975-03', '1975-04', '1975-05', '1975-06',
#              '1975-07', '1975-08', '1975-09', '1975-10', '1975-11', '1975-12'],
#             dtype='period[M]', is_relative=False)

# %% [markdown]
# Exponential Smoothing (HW)

# %%
forecaster = ExponentialSmoothing(trend="add", seasonal="additive", sp=12)
forecaster.fit(y_train)
y_pred = forecaster.predict(fh)

# %%
plot_series(y_train, y_test, y_pred, labels=["y_train", "y_test", "y_pred"])
plt.show()
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
print(mean_squared_error(y_test, y_pred,square_root=True))
# Out:
# 11.932357030841406

# %% [markdown]
# State Space Models Approach:

# %%
forecaster = AutoETS(auto=True, sp=12)
forecaster.fit(y_train)
y_pred = forecaster.predict(fh)
plot_series(y_train, y_test, y_pred, labels=["y_train", "y_test", "y_pred"])
plt.show()
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
print(forecaster.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  156
# Model:                       ETS(AAA)   Log Likelihood                -527.851
# Date:                Sat, 13 Jan 2024   AIC                           1091.703
# Time:                        11:40:14   BIC                           1146.600
# Sample:                    01-31-1962   HQIC                          1114.000
#                          - 12-31-1974   Scale                           50.879
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.6986      0.078      8.980      0.000       0.546       0.851
# smoothing_trend      6.986e-05        nan        nan        nan         nan         nan
# smoothing_seasonal      0.2120      0.055      3.836      0.000       0.104       0.320
# initial_level         587.2733        nan        nan        nan         nan         nan
# initial_trend           1.6175      0.415      3.901      0.000       0.805       2.430
# initial_seasonal.0    -23.7715        nan        nan        nan         nan         nan
# initial_seasonal.1    -58.5394        nan        nan        nan         nan         nan
# initial_seasonal.2    -35.0911        nan        nan        nan         nan         nan
# initial_seasonal.3    -37.9175        nan        nan        nan         nan         nan
# initial_seasonal.4      2.6534        nan        nan        nan         nan         nan
# initial_seasonal.5     50.5657        nan        nan        nan         nan         nan
# initial_seasonal.6    108.1809        nan        nan        nan         nan         nan
# initial_seasonal.7    134.6573        nan        nan        nan         nan         nan
# initial_seasonal.8     69.5707        nan        nan        nan         nan         nan
# initial_seasonal.9     55.1748        nan        nan        nan         nan         nan
# initial_seasonal.10   -29.1856        nan        nan        nan         nan         nan
# initial_seasonal.11          0        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (Q):                       21.85   Jarque-Bera (JB):                14.75
# Prob(Q):                              0.59   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.43   Skew:                             0.45
# Prob(H) (two-sided):                  0.20   Kurtosis:                         4.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %%
print(mean_squared_error(y_test, y_pred,square_root=True))
# Out:
# 12.010118959027817
