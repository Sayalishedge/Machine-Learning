# %%
# !pip install sktime
# Out:
# Requirement already satisfied: sktime in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (0.25.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from sktime) (1.26.3)
# Requirement already satisfied: packaging in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from sktime) (23.1)
# Requirement already satisfied: pandas<2.2.0,>=1.1 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from sktime) (2.1.4)
# Requirement already satisfied: scikit-base<0.7.0 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from sktime) (0.6.2)
# Requirement already satisfied: scikit-learn<1.4.0,>=0.24 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from sktime) (1.2.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from sktime) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from pandas<2.2.0,>=1.1->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from pandas<2.2.0,>=1.1->sktime) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from pandas<2.2.0,>=1.1->sktime) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from scikit-learn<1.4.0,>=0.24->sktime) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from scikit-learn<1.4.0,>=0.24->sktime) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.2.0,>=1.1->sktime) (1.16.0)

# %%
import os
#os.chdir("/content/drive/MyDrive/Datasets")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sktime.forecasting.compose import make_reduction
from sklearn.ensemble import RandomForestRegressor
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.performance_metrics.forecasting import MeanSquaredError
from sktime.utils.plotting import plot_series
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\dask\dataframe\_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 11.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(

# %%
df = pd.read_csv("F:\PML\Datasets\BUNDESBANK-BBK01_WT5511.csv",index_col=0)
idx = pd.to_datetime( df.index ).to_period("M")
df.index = idx
# Out:
# C:\Users\dbda\AppData\Local\Temp\ipykernel_4704\1344177289.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   idx = pd.to_datetime( df.index ).to_period("M")

# %%
y_train, y_test = temporal_train_test_split(df,test_size=6)

# %%
y_train.shape
# Out:
# (571, 1)

# %%
y_test.shape
# Out:
# (6, 1)

# %%
fh = np.arange(1, len(y_test) + 1)  # forecasting horizon
fh
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
regressor = RandomForestRegressor(random_state=23)

# %%
forecaster = make_reduction(regressor,window_length=7)
forecaster
# Out:
# RecursiveTabularRegressionForecaster(estimator=RandomForestRegressor(random_state=23),
#                                      window_length=7)

# %%
forecaster.fit(y_train)
# Out:
# RecursiveTabularRegressionForecaster(estimator=RandomForestRegressor(random_state=23),
#                                      window_length=7)

# %%
y_pred = forecaster.predict(fh)
rmse = MeanSquaredError(square_root=True)
print(rmse(y_test, y_pred))
# Out:
# 88.9346408045911

# %%
plot_series(y_train,y_test,y_pred , labels=['Train','Test','Forecast'])
plt.show()
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plot_series(y_test,y_pred , labels=['Test','Forecast'])
plt.show()
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Basic Grid Search**

# %%
from sktime.forecasting.compose import make_reduction
from sktime.forecasting.model_selection import ForecastingGridSearchCV, SlidingWindowSplitter

# %%
forecaster = make_reduction(regressor, window_length=15, strategy="recursive")
param_grid = {"window_length": [6,7,8,9,10]}

# %% [markdown]
# We fit the forecaster on an initial window which is 80% of the historical data
# then use temporal sliding window cross-validation to find the optimal hyper-parameters

# %%
cv = SlidingWindowSplitter(initial_window=int(len(y_train) * 0.8), window_length=20)
gscv = ForecastingGridSearchCV(
    forecaster, strategy="refit", cv=cv, param_grid=param_grid
)

# %%
gscv.fit(y_train)
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\sktime\forecasting\model_selection\_tune.py:198: UserWarning: in ForecastingGridSearchCV, n_jobs and pre_dispatch parameters are deprecated and will be removed in 0.26.0. Please use n_jobs and pre_dispatch directly in the backend_params argument instead.
#   warn(
# ForecastingGridSearchCV(cv=SlidingWindowSplitter(initial_window=456,
#                                                  window_length=20),
#                         forecaster=RecursiveTabularRegressionForecaster(estimator=RandomForestRegressor(random_state=23),
#                                                                         window_length=15),
#                         param_grid={'window_length': [6, 7, 8, 9, 10]})

# %%
print(gscv.best_params_)
# Out:
# {'window_length': 6}

# %%
print(gscv.best_score_)
# Out:
# 0.05091505841210757

# %%
y_pred = gscv.predict(fh)
plot_series(y_train, y_test, y_pred, labels=["y_train", "y_test", "y_pred"])
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# (<Figure size 1600x400 with 1 Axes>, <Axes: >)

# %%
print(rmse(y_test, y_pred))
# Out:
# 91.16711706325368

# %% [markdown]
# **Composite Grid Search**

# %%
forecaster = make_reduction(regressor, window_length=15, strategy="recursive")
param_grid = {"window_length": [6,7,8,9,10],
              'estimator__max_features':[2,3,4,5]}
cv = SlidingWindowSplitter(initial_window=int(len(y_train) * 0.8), window_length=20)
gscv = ForecastingGridSearchCV(forecaster, strategy="refit", cv=cv, param_grid=param_grid)

# %%
gscv.fit(y_train)
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\sktime\forecasting\model_selection\_tune.py:198: UserWarning: in ForecastingGridSearchCV, n_jobs and pre_dispatch parameters are deprecated and will be removed in 0.26.0. Please use n_jobs and pre_dispatch directly in the backend_params argument instead.
#   warn(
# ForecastingGridSearchCV(cv=SlidingWindowSplitter(initial_window=456,
#                                                  window_length=20),
#                         forecaster=RecursiveTabularRegressionForecaster(estimator=RandomForestRegressor(random_state=23),
#                                                                         window_length=15),
#                         param_grid={'estimator__max_features': [2, 3, 4, 5],
#                                     'window_length': [6, 7, 8, 9, 10]})

# %%
print(gscv.best_params_)
# Out:
# {'estimator__max_features': 5, 'window_length': 6}

# %%
print(gscv.best_score_)
# Out:
# 0.050665031023722294

# %%
y_pred = gscv.predict(fh)
plot_series(y_train, y_test, y_pred, labels=["y_train", "y_test", "y_pred"])
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# (<Figure size 1600x400 with 1 Axes>, <Axes: >)

# %%
print(rmse(y_test, y_pred))
# Out:
# 87.4856737624319

# %%
plot_series(y_test,y_pred , labels=['Test','Forecast'])
plt.show()
# Out:
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dbda\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
