# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
 df=pd.read_csv("F://PML//day1//Housing (1).csv")

# %%
df
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
df.columns
# Out:
# Index(['price', 'lotsize', 'bedrooms', 'bathrms', 'stories', 'driveway',
#        'recroom', 'fullbase', 'gashw', 'airco', 'garagepl', 'prefarea'],
#       dtype='object')

# %%
df.dtypes
# Out:
# price       float64
# lotsize       int64
# bedrooms      int64
# bathrms       int64
# stories       int64
# driveway     object
# recroom      object
# fullbase     object
# gashw        object
# airco        object
# garagepl      int64
# prefarea     object
# dtype: object

# %%
import matplotlib.pyplot as plt
plt.scatter(df['lotsize'],df['price'])
plt.xlabel('Area')
plt.ylabel('aa')
# Out:
# Text(0, 0.5, 'aa')

# %%
df['lotsize'].corr(df['price'])
# Out:
# 0.535795672432184

# %%
x=df['lotsize']
print(type(x))
# Out:
# <class 'pandas.core.series.Series'>

# %%
lr =LinearRegression()
x=df[['lotsize']] #we are keeping double square bracket because of datatype x must be 2d 
y=df['price']
lr.fit(x,y)
print(lr.intercept_, lr.coef_)
# Out:
# 34136.19156491507 [6.59876759]

# %%
ycap=34136.19156491507 +df['lotsize'] * 6.59876759
print(ycap)
# Out:
# 0      72738.981966
# 1      60531.261925
# 2      54328.420390
# 3      78017.996038
# 4      76104.353437
#            ...
# 541    65810.275997
# 542    73728.797105
# 543    73728.797105
# 544    73728.797105
# 545    73728.797105
# Name: lotsize, Length: 546, dtype: float64

# %%
lr =LinearRegression()
x=df[['lotsize','bedrooms']] #we are keeping double square bracket because of datatype x must be 2d 
y=df['price']
lr.fit(x,y)
print(lr.intercept_, lr.coef_)
# Out:
# 5612.599731057468 [6.05302208e+00 1.05673515e+04]

# %%
x=df[['lotsize']] #this is 2d
print(x.shape)
x=df['lotsize']  #this is 1d
print(x.shape)
# Out:
# (546, 1)
# (546,)

# %%
#5612.599731057468=b0
#1.05673515e+04=b1
print("predicted value for lotsize only")
y=5612.599731057468 +4000 * 1.05673515e+04
print(y)
print()
ycap=5612.599731057468 + df['lotsize'] * 1.05673515e+04
print(ycap)
ycap.values
# Out:
#         39944.83791106,  51567.99222546,  46807.55620466,  57704.84608416,
# ...

# %%
np.sum((y-ycap)**2)
# Out:
# 9.725271172725875e+17

# %%
#include bathroom also

# %%
lr =LinearRegression()
x=df[['lotsize','bedrooms','bathrms']] #we are keeping double square bracket because of datatype x must be 2d 
y=df['price']
lr.fit(x,y)
print(lr.intercept_, lr.coef_)
# Out:
# -2418.292616740713 [5.41120044e+00 5.82680241e+03 1.97502101e+04]

# %%
print("predicted value is for lotsize and bedroom and bathrooms")
y=-2418.292616740713 +4000 * 6.59876759
print(y)
ycap=-2418.292616740713+df['lotsize']* 6.59876759+df['bedrooms']*1.05673515e+04+ df["bathrms"]*1.97502101e+04
print(ycap)
# Out:
# predicted value is for lotsize and bedroom and bathrooms
# 23976.777743259285
# 0       87636.762385
# 1       64861.690843
# 2       69226.200809
# 3       92915.776457
# 4       80434.782356
#            ...
# 541    100458.266515
# 542    108376.787623
# 543    108376.787623
# 544    108376.787623
# 545     88626.577523
# Length: 546, dtype: float64

# %%
np.sum((y-ycap)**2)
# Out:
# 2536855436514.548

# %%
'''
plt.scatter(ycap,y)
plt.xlabel("estimated y")
plt.ylabel("Actual Y")
plt.show()

'''
# Out:
# '\nplt.scatter(ycap,y)\nplt.xlabel("estimated y")\nplt.ylabel("Actual Y")\nplt.show()\n\n'

# %%
#add driveway 
#convert data type of driveway

# %%
df['driveway']=np.where(df['driveway'] == "yes", 1,0)
df
# Out:
#         price  lotsize  bedrooms  bathrms  stories  driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2         1      no      yes
# 1     38500.0     4000         2        1        1         1      no       no
# 2     49500.0     3060         3        1        1         1      no       no
# 3     60500.0     6650         3        1        2         1     yes       no
# 4     61000.0     6360         2        1        1         1      no       no
# ..        ...      ...       ...      ...      ...       ...     ...      ...
# 541   91500.0     4800         3        2        4         1     yes       no
# 542   94000.0     6000         3        2        4         1      no       no
# 543  103000.0     6000         3        2        4         1     yes       no
# 544  105000.0     6000         3        2        2         1     yes       no
# 545  105000.0     6000         3        1        2         1      no       no
#
# ...

# %%
lr =LinearRegression()
x=df[['lotsize','bedrooms','bathrms','driveway']] #we are keeping double square bracket because of datatype x must be 2d 
y=df['price']
lr.fit(x,y)
print(lr.intercept_, lr.coef_)
# Out:
# -11501.414051187327 [4.78495477e+00 6.19654687e+03 1.96887926e+04 1.31448062e+04]

# %%
print("predicted value is for lotsize and bedroom and bathrooms and driveway")

ycap=-11501.414051187327+df['lotsize']*4.78495477e+00 +df['bedrooms']* 6.19654687e+03 + df["bathrms"]* 1.96887926e+04 +df["driveway"] * 1.31448062e+04
print(ycap)
# Out:
# predicted value is for lotsize and bedroom and bathrooms and driveway
# 0      67913.810763
# 1      52865.097569
# 2      54563.786955
# 3      71741.774579
# 4      64157.590826
#            ...
# 541    82578.400855
# 542    88320.346579
# 543    88320.346579
# 544    88320.346579
# 545    68631.553979
# Length: 546, dtype: float64

# %%
#or
y=lr.predict(x)
print(y)
# Out:
# [ 67913.81082622  52865.09762656  54563.78700463  71741.77464604
#   64157.59089501  59827.23725687  78176.24256782  59827.23725687
#   62889.60831272  85927.86930294  94062.29242004  34935.33665368
#   48056.24851095  40557.68894705  50951.11571666  48965.35948513
#   42567.36995245  71000.13708897  44036.8256341   59342.09470949
#   62817.8339911   87387.31094227  59061.64449291  52549.29061143
#   57458.65421034  48080.1428518   51908.10667161  57458.65421034
#   41131.88352003  61454.12188029  37327.81404106  62865.71397187
#   52865.09762656  55257.57501395  64157.59089501  55257.57501395
#   53018.21617936  64660.04157938  91645.92069181  55341.87251778
#   57841.48102534  61549.82097579  68320.5624151  132747.41638979
#   43295.18807703  37112.52150922  35126.73484467  41562.52944975
#   56706.94174491  55951.42388931  97363.97208068  52591.88063861
#   77584.173993    59253.0426839   83523.9903239   51046.81481215
# ...

# %%
np.sum((y-ycap)**2)
# Out:
# 189190016788.43976

# %%
plt.scatter(ycap,y)
plt.xlabel("estimated y")
plt.ylabel("Actual Y")
plt.show()

# %%
df
# Out:
#         price  lotsize  bedrooms  bathrms  stories  driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2         1      no      yes
# 1     38500.0     4000         2        1        1         1      no       no
# 2     49500.0     3060         3        1        1         1      no       no
# 3     60500.0     6650         3        1        2         1     yes       no
# 4     61000.0     6360         2        1        1         1      no       no
# ..        ...      ...       ...      ...      ...       ...     ...      ...
# 541   91500.0     4800         3        2        4         1     yes       no
# 542   94000.0     6000         3        2        4         1      no       no
# 543  103000.0     6000         3        2        4         1     yes       no
# 544  105000.0     6000         3        2        2         1     yes       no
# 545  105000.0     6000         3        1        2         1      no       no
#
# ...

# %%
#reloading the data bcoz want in a original form
df1=pd.read_csv("F://PML//day1//Housing (1).csv")
df1
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
pd.get_dummies(df1)
# Out:
#         price  lotsize  bedrooms  bathrms  stories  garagepl  driveway_no  \
# 0     42000.0     5850         3        1        2         1        False
# 1     38500.0     4000         2        1        1         0        False
# 2     49500.0     3060         3        1        1         0        False
# 3     60500.0     6650         3        1        2         0        False
# 4     61000.0     6360         2        1        1         0        False
# ..        ...      ...       ...      ...      ...       ...          ...
# 541   91500.0     4800         3        2        4         0        False
# 542   94000.0     6000         3        2        4         0        False
# 543  103000.0     6000         3        2        4         1        False
# 544  105000.0     6000         3        2        2         1        False
# 545  105000.0     6000         3        1        2         1        False
#
#      driveway_yes  recroom_no  recroom_yes  fullbase_no  fullbase_yes  \
# ...

# %%
#True+False
#above True ,False are numerical values

# %% [markdown]
# one hot encoding /dummying

# %%
dum_hous=pd.get_dummies(df1, drop_first=True)
dum_hous
# Out:
#         price  lotsize  bedrooms  bathrms  stories  garagepl  driveway_yes  \
# 0     42000.0     5850         3        1        2         1          True
# 1     38500.0     4000         2        1        1         0          True
# 2     49500.0     3060         3        1        1         0          True
# 3     60500.0     6650         3        1        2         0          True
# 4     61000.0     6360         2        1        1         0          True
# ..        ...      ...       ...      ...      ...       ...           ...
# 541   91500.0     4800         3        2        4         0          True
# 542   94000.0     6000         3        2        4         0          True
# 543  103000.0     6000         3        2        4         1          True
# 544  105000.0     6000         3        2        2         1          True
# 545  105000.0     6000         3        1        2         1          True
#
#      recroom_yes  fullbase_yes  gashw_yes  airco_yes  prefarea_yes
# ...

# %%
#recommended
dum_hous=pd.get_dummies(df1,drop_first=True)
x=dum_hous.drop('price',axis=1)
y=dum_hous['price']
print(x)
#another way

#x=dum_hous.iloc[:,1:]
#print(x)
#x
# Out:
#      lotsize  bedrooms  bathrms  stories  garagepl  driveway_yes  recroom_yes  \
# 0       5850         3        1        2         1          True        False
# 1       4000         2        1        1         0          True        False
# 2       3060         3        1        1         0          True        False
# 3       6650         3        1        2         0          True         True
# 4       6360         2        1        1         0          True        False
# ..       ...       ...      ...      ...       ...           ...          ...
# 541     4800         3        2        4         0          True         True
# 542     6000         3        2        4         0          True        False
# 543     6000         3        2        4         1          True         True
# 544     6000         3        2        2         1          True         True
# 545     6000         3        1        2         1          True        False
#
# ...

# %%
lr=LinearRegression()
lr.fit(x,y)
print(lr.intercept_,lr.coef_)
# Out:
# -4038.350425098368 [3.54630297e+00 1.83200347e+03 1.43355585e+04 6.55694571e+03
#  4.24482900e+03 6.68777889e+03 4.51128383e+03 5.45238554e+03
#  1.28314063e+04 1.26328904e+04 9.36951324e+03]

# %%
ycap=lr.predict(x)

# %%
np.sum((y-ycap)**2)
# Out:
# 127025071644.46799

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y,ycap)
# Out:
# 232646651.3634945
